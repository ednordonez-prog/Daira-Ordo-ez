# %%
val1 = 5
val2 = 7
res = val1 % val2
print(res)
# Out:
# 5

# %%
val1 = int(input("give me a number: "))
val2 = int(input("give me another number: "))
res = val1 % val2
print(res)
# Out:
# 5

# %%
val1 = int(input("give me a number: ")) 
val2 = int(input("give me another number: "))

res = val1 % val2
print(res)

multi = val1 * val2
print(f"the product of both numbers is: {multi}")

if multi % 2 == 0:
    print("your number is even!")
else:
    print("your number is odd")
# Out:
# 5
# the product of both numbers is: 50
# your number is even!

# %%
n = int(input("How many numbers?: "))

lista = []

a, b = 1, 1

for i in range(n):
    lista.append(a)
    a, b = b, a + b

print(lista)
# Out:
# [1, 1, 2, 3, 5, 8, 13, 21]
